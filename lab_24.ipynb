# %% [markdown]
# <a href="https://colab.research.google.com/github/pranaviellendula0/pranaviellendula/blob/main/lab_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create two Boolean objects
bool1 = True
bool2 = False

# Use the 'and' operator in an if statement
if bool1 and bool2:
    print("Both conditions are True.")
else:
    print("At least one condition is False.")
# Out:
# At least one condition is False.
