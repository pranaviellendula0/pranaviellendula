# %% [markdown]
# <a href="https://colab.research.google.com/github/pranaviellendula0/pranaviellendula/blob/main/lab_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name: ")
# Out:
# Enter your name: pranavi

# %%
x, y = map(int, input("Enter two numbers separated by space: ").split())
print(f"Sum of {x} and {y} is: {x + y}")
# Out:
# Enter two numbers separated by space: 5 2
# Sum of 5 and 2 is: 7

# %%
marks = int(input("Enter your marks (out of 100): "))

if marks >= 50:
    print("Congratulations! You passed the exam.")
else:
    print("Sorry, you failed. Better luck next time.")
# Out:
# Enter your marks (out of 100): 60
# Congratulations! You passed the exam.

# %%
age = int(input("Enter your age: "))
# Out:
# Enter your age: 21
